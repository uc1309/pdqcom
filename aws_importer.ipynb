# %%
import numpy as np
import pandas as pd
import sqlite3
from sqlalchemy import create_engine
from sqlalchemy import types

from pandas import DataFrame, Series

# %%
engine = create_engine('mysql://tutorial_user:JHU2005TG@tutorial-db-instance.clgwlve8evs0.us-east-1.rds.amazonaws.com:3306/pdq?charset=utf8', encoding='utf8')

# %%
DF_obj = DataFrame()
for chunk in pd.read_csv('C:\\Users\\arxli\\Documents\\00002_UChicago Second Year\\Personal\\Career Advancement\\PDQ Communications\\npidata_pfile_20050523-20180909\\npidata_pfile_20050523-20180909.csv', parse_dates = True, encoding = 'utf8', chunksize = 100000, usecols=list(range(52))):
    DF_obj = chunk
    #DF_obj = pd.concat([DF_obj, chunk])
    DF_obj['NPI Deactivation Date'] = pd.to_datetime(DF_obj['NPI Deactivation Date'])
    DF_obj['NPI Reactivation Date'] = pd.to_datetime(DF_obj['NPI Reactivation Date'])
    DF_obj['Last Update Date'] = pd.to_datetime(DF_obj['Last Update Date'])
    DF_obj['Provider Enumeration Date'] = pd.to_datetime(DF_obj['Provider Enumeration Date'])
    DF_obj.rename(columns={'Provider Business Mailing Address Country Code (If outside U.S.)': 'Provider Business Mailing Address Country Code', 'Provider Business Practice Location Address Country Code (If outside U.S.)': 'Provider Business Practice Location Address Country Code'}, inplace=True)
    print('Blasting data...')
    DF_obj.to_sql('npidata_auto', con=engine, if_exists='append', index_label='id', dtype = {'Provider Business Mailing Address Fax Number': types.Text(), 'Provider Business Practice Location Address Fax Number': types.Text(), 'Authorized Official Telephone Number': types.Text()})
DF_obj
# Out:
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# c:\users\arxli\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3018: DtypeWarning: Columns (17,24,32,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Blasting data...
# c:\users\arxli\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3018: DtypeWarning: Columns (17,24,32,40,46) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
DF_obj['Provider Business Mailing Address Postal Code']
# Out:
# 5700000    760181698
# 5700001    672112805
# 5700002    430687170
# 5700003    846011677
# 5700004    410172518
# 5700005    761352835
# 5700006    400659117
# 5700007    104691549
# 5700008    360222567
# 5700009    653018061
# 5700010    483771624
# 5700011    730995264
# 5700012    329552424
# 5700013    452271491
# 5700014    152058702
# 5700015    762279231
# 5700016    208532751
# 5700017    460528622
# 5700018    672267678
# 5700019    468188680
# 5700020    770276137
# 5700021    109775333
# 5700022    104651367
# 5700023    781542626
# 5700024    243820242
# 5700025    917682358
# 5700026    206015225
# 5700027    328325122
# 5700028    336132920
# 5700029    871232415
#              ...
# 5725824    334411817
# 5725825    900170016
# 5725826    023024505
# 5725827    230615307
# 5725828    296517196
# 5725829    750014648
# 5725830    133572258
# 5725831    019231398
# 5725832    170032137
# 5725833    212284118
# 5725834    465629106
# 5725835    775845269
# ...

# %%
DF_obj = DataFrame()
filepath = 'C:\\Users\\arxli\\Documents\\00002_UChicago Second Year\\Personal\\Career Advancement\\PDQ Communications\\PartD_Prescriber_PUF_NPI_Drug_16\\PartD_Prescriber_PUF_NPI_Drug_16.csv'
counter = 0
for chunk in pd.read_csv(filepath, delimiter = '\t', encoding = 'utf8', chunksize = 100000, usecols = list(range(11))):
    DF_obj = chunk
    #DF_obj = pd.concat([DF_obj,chunk])
    print('Blasting data...')
    if counter:
        DF_obj.to_sql('mpdata2016_auto', con=engine, if_exists='append', index_label='id')
    else:
        DF_obj.to_sql('mpdata2016_auto', con=engine, if_exists='replace', index_label='id')
        counter += 1
DF_obj
# Out:
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# Blasting data...
# ...

# %%
# Out:
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
# 5            NaT
# 6            NaT
# 7            NaT
# 8            NaT
# 9            NaT
# 10           NaT
# 11           NaT
# 12           NaT
# 13           NaT
# 14           NaT
# 15           NaT
# 16           NaT
# 17           NaT
# 18           NaT
# 19           NaT
# 20           NaT
# 21           NaT
# 22           NaT
# 23           NaT
# 24           NaT
# 25           NaT
# 26           NaT
# 27           NaT
# 28    2005-05-24
# 29           NaT
#          ...
# 470          NaT
# 471          NaT
# 472          NaT
# 473          NaT
# 474          NaT
# 475          NaT
# 476          NaT
# 477          NaT
# 478          NaT
# 479          NaT
# 480          NaT
# 481          NaT
# 482          NaT
# 483          NaT
# 484          NaT
# 485          NaT
# 486          NaT
# 487          NaT
# 488          NaT
# 489          NaT
# 490          NaT
# ...
